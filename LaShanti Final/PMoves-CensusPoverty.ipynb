# %%
# Placement Moves per 1,000 Bed Days in Foster Care 
# Measure:The rate at which children change placements while in Foster care
# The purpose of this chart it to compare the placement moves % by regions 2009-2019Q2

# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV
placement_moves = pd.read_csv("Resources/pmregions.csv")

placement_moves
# Out:
#         Entity TotalRegions  RegionAvg FEMALE FY 2019 Q2 FEMALE FY 2019 Q1  \
# 0    Central         93,396          9             1,064             1,149
# 1  Northeast         54,760         10               757               742
# 2   Northwest        44,076         12               797               756
# 3   Southeast        64,415         15               695               774
# 4    Southern        40,546         21               484               555
# 5    Suncoast       143,936         33             1,853             1,947
#
#   FEMALE FY 2018 Q4 FEMALE FY 2018 Q3 FEMALE FY 2018 Q2 FEMALE FY 2018 Q1  \
# 0             1,137             1,182             1,134             1,139
# 1               631               624               677               726
# 2               644               565               510               460
# 3               808               856               792               737
# ...

# %%
# Filter the datframe for colums Entity & Total
piechart = placement_moves[["Entity","RegionAvg"]]

piechart
# Out:
#         Entity  RegionAvg
# 0    Central            9
# 1  Northeast           10
# 2   Northwest          12
# 3   Southeast          15
# 4    Southern          21
# 5    Suncoast          33

# %%
# Labels for the sections of our pie chart
labels = ["Central", "Northeast", "Northwest", "Southeast", "Southern","Suncoast"]

# The values of each section of the pie chart
sizes = [9, 10, 12, 15, 21,33]

# The colors of each section of the pie chart
colors = ["orange", "lightblue", "purple", "green", "gray", "red"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0, 0,0,.1)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=145)

plt.title("2009-2019 Foster Care Placement Moves Per 1,000 Bed Days By Region")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, '2009-2019 Foster Care Placement Moves Per 1,000 Bed Days By Region')

# %%
plt.tight_layout()
plt.savefig("Images/PlacementMovesPieChartByRegion")
plt.show()

# %%
# Placement Moves per 1,000 Bed Days in Foster Care 
# Measure:The rate at which children change placements while in Foster care
# The purpose of this chart it to compare the placement moves % male vs.female 2009-2019Q2

# %%
# Read CSV
placement_moves = pd.read_csv("Resources/pmmalevfemale.csv")

placement_moves
# Out:
#         Entity Total Female Total Male      All  FemalePercentage  \
# 0    Central         43,820     49,576   93,396                47
# 1  Northeast         26,329     28,431   54,760                48
# 2   Northwest        21,213     22,863   44,076                48
# 3   Southeast        30,998     33,417   64,415                48
# 4    Southern        20,762     19,784   40,546                51
# 5    Suncoast        67,281     76,655  143,936                47
#
#    MalePercentage FEMALE FY 2019 Q2 FEMALE FY 2019 Q1 FEMALE FY 2018 Q4  \
# 0              53             1,064             1,149             1,137
# 1              52               757               742               631
# 2              52               797               756               644
# 3              52               695               774               808
# 4              49               484               555               573
# ...

# %%
# Filter the placement_moves for colums "Entity","FemalePercentage","MalePercentage"
bargraph = placement_moves[["Entity","FemalePercentage","MalePercentage"]]

bargraph.head()
# Out:
#         Entity  FemalePercentage  MalePercentage
# 0    Central                  47              53
# 1  Northeast                  48              52
# 2   Northwest                 48              52
# 3   Southeast                 48              52
# 4    Southern                 51              49

# %%
bargraph.set_index('Entity').plot.bar(rot=0, title='2009-2019 Foster Care Placement Moves Per 1,000 Bed Days By Gender',
                                      figsize=(10,5), fontsize=12)
plt.xlabel("Florida Regions")
plt.ylabel("% of Placement Moves")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0, 0.5, '% of Placement Moves')

# %%
plt.tight_layout()
plt.savefig("Images/PlacementMovesBarChartByGender")
plt.show()

# %%
# Placement Moves per 1,000 Bed Days in Foster Care 
# Measure:The rate at which children change placements while in Foster care
# The purpose of this chart it to compare the placement moves % by race, 2009-2019Q2

# %%
# Read CSV
placement_moves = pd.read_csv("Resources/pmrace.csv")

placement_moves
# Out:
#        Entity  Multi  Black  White  Multi FY 2009 Q1  Multi FY 2009 Q2  \
# 0    Central    7717  25626  60053               114               114
# 1   Northeast   4372  19215  31173                87                69
# 2  Northwest    4717  12178  27181               148               137
# 3   Southeast   4414  33567  26434                85               116
# 4   Southern    1772  22738  16036                17                15
# 5    Suncoast  12118  41076  90742               231               164
#
#    Multi FY 2009 Q3  Multi FY 2009 Q4  Multi FY 2010 Q1  Multi FY 2010 Q2  \
# 0               128               137               161               162
# 1                81                79                65                76
# 2                88                75                53                61
# 3                89                80                56                44
# 4                19                15                22                15
# ...

# %%
# Filter the placement_moves for colums "Entity","FemalePercentage","MalePercentage"
bargraph = placement_moves[["Entity","Multi","Black","White"]]

bargraph.head()
# Out:
#        Entity  Multi  Black  White
# 0    Central    7717  25626  60053
# 1   Northeast   4372  19215  31173
# 2  Northwest    4717  12178  27181
# 3   Southeast   4414  33567  26434
# 4   Southern    1772  22738  16036

# %%
bargraph.set_index('Entity').plot.bar(rot=45, title='2009-2019 Foster Care Placement Moves Per 1,000 Bed Days By Race',
                                      figsize=(8,5), fontsize=12)
plt.xlabel("Florida Regions")
plt.ylabel("% of Placement Moves")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0, 0.5, '% of Placement Moves')

# %%
plt.tight_layout()
plt.savefig("Images/PlacementMovesBarChartByRace")
plt.show()

# %%
# Percent; Estimate; POVERTY RATE FOR THE POPULATION 
# 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL

# %%
# Read CSV
poverty_rates = pd.read_csv("Resources/acs_2009to2017_5yr_s1501.csv")

poverty_rates.head()
# Out:
#      County  2009Dropout  2009  - High school graduate (includes equivalency)  \
# 0   Alachua         35.6                                               13.2
# 1     Baker         29.5                                               17.5
# 2  Bradford         20.9                                               12.9
# 3      Clay         16.3                                                8.1
# 4  Columbia         27.0                                               13.5
#
#    2009 - Some college or associate's degree  \
# 0                                       10.6
# 1                                        7.7
# 2                                       11.6
# 3                                        4.9
# 4                                       11.4
#
#    2009 - Bachelor's degree or higher  2010Dropout  \
# 0                                 6.0         36.0
# 1                                 2.4         30.3
# 2                                 9.5         22.6
# ...

# %%
# Filter the placement_moves for HighSchool Dropout data
censusbargraph = poverty_rates[["County","2009Dropout","2010Dropout","2011Dropout","2012Dropout","2013Dropout",
                                "2014Dropout","2015Dropout","2016Dropout","2017Dropout"]]

censusbargraph.head()
# Out:
#      County  2009Dropout  2010Dropout  2011Dropout  2012Dropout  2013Dropout  \
# 0   Alachua         35.6         36.0         32.6         33.1         36.4
# 1     Baker         29.5         30.3         24.8         34.3         38.2
# 2  Bradford         20.9         22.6         27.4         27.4         28.7
# 3      Clay         16.3         17.8         18.6         20.7         22.0
# 4  Columbia         27.0         27.3         26.6         28.5         28.6
#
#    2014Dropout  2015Dropout  2016Dropout  2017Dropout
# 0         37.4         36.0         37.5         37.3
# 1         38.9         39.7         38.5         37.1
# 2         31.0         29.9         30.6         29.8
# 3         24.0         24.3         24.5         23.7
# 4         33.3         32.9         34.2         32.5

# %%
censusbargraph.set_index('County').plot.bar(rot=90, title='Poverty Rates by County Age 25+ High School Dropout 2009-2017',

                                            figsize=(25,4), fontsize=8,)
plt.xlabel("Florida Regions")
plt.ylabel("% Poverty Rate ")
# Out:
# <img src="data:image/png;base64,..." width="2500">
# Text(0, 0.5, '% Poverty Rate ')

# %%
plt.legend(labels, bbox_to_anchor=(0.85,1.025), loc="best")
plt.tight_layout()
plt.savefig("Images/'PovertyRatesbyCountyAge25+HighSchoolDropout2009-2017'")
plt.show()

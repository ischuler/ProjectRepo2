# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#CSV file
income_florida = "income_florida.csv"
income_disparity = pd.read_csv(income_florida)

income_disparity
# Out:
#     year     region average income
# 0   2013  Northwest       $43,655
# 1   2014  Northwest       $43,891
# 2   2015  Northwest       $44,014
# 3   2016  Northwest       $45,088
# 4   2013  Northeast       $45,148
# 5   2014  Northeast       $44,013
# 6   2015  Northeast       $43,838
# 7   2016  Northeast       $43,658
# 8   2013    Central       $43,890
# 9   2014    Central       $44,125
# 10  2015    Central       $44,374
# 11  2016    Central       $45,455
# 12  2013   Suncoast       $44,988
# 13  2014   Suncoast       $43,964
# 14  2015   Suncoast       $43,709
# 15  2016   Suncoast       $43,512
# 16  2013   Southern       $44,633
# 17  2014   Southern       $49,274
# 18  2015   Southern       $48,354
# 19  2016   Southern       $52,264
# 20  2013  Southeast       $43,067
# 21  2014  Southeast       $43,260
# 22  2015  Southeast       $43,489
# 23  2016  Southeast       $44,529

# %%
#Scatterplot for Unemployment Rates

labels = ["Suncoast", "Southern", "Southeast", "Northwest", "Northeast", "Central"]

sizes = [2.8, 3.15, 3.23, 4.08, 3.28, 3.58]

plt.bar(labels, sizes)
plt.xlabel('Regions', fontsize=5)
plt.ylabel('Unemployment Rate', fontsize=5)
plt.title("Unemployment Rate Avg by Region (2008-2018)")
# Out:
# Text(0.5, 1.0, 'Unemployment Rate Avg by Region (2008-2018)')
